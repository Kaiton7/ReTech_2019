# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
train = pd.read_csv("../../input/train.csv")
test = pd.read_csv("../../input/test.csv")

# %% [markdown]
# ### 42~57

# %%
cat_column = ["Electrical", "KitchenQual", "Functional", "FireplaceQu"]

# %%
for i in cat_column:
    data = pd.concat([train['SalePrice'], train[i]], axis=1)
    f, ax = plt.subplots(figsize=(8, 6))
    fig = sns.boxplot(x=i, y="SalePrice", data=data)
    fig.axis(ymin=0, ymax=800000);

# %% [markdown]
# ### 全部

# %%
for i in train.select_dtypes(include=['object']).columns:
    data = pd.concat([train['SalePrice'], train[i]], axis=1)
    f, ax = plt.subplots(figsize=(8, 6))
    fig = sns.boxplot(x=i, y="SalePrice", data=data)
    fig.axis(ymin=0, ymax=800000)
# Out:
# /home/ravrik/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py:514: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)

# %%
train[train["YearBuilt"] < 1950].count()
# Out:
# Id               318
# MSSubClass       318
# MSZoning         318
# LotFrontage      290
# LotArea          318
# Street           318
# Alley             63
# LotShape         318
# LandContour      318
# Utilities        318
# LotConfig        318
# LandSlope        318
# Neighborhood     318
# Condition1       318
# Condition2       318
# BldgType         318
# HouseStyle       318
# OverallQual      318
# OverallCond      318
# YearBuilt        318
# YearRemodAdd     318
# RoofStyle        318
# RoofMatl         318
# Exterior1st      318
# Exterior2nd      318
# MasVnrType       318
# MasVnrArea       318
# ExterQual        318
# ExterCond        318
# Foundation       318
#                 ...
# BedroomAbvGr     318
# KitchenAbvGr     318
# KitchenQual      318
# TotRmsAbvGrd     318
# Functional       318
# Fireplaces       318
# FireplaceQu      127
# GarageType       268
# GarageYrBlt      268
# GarageFinish     268
# GarageCars       318
# GarageArea       318
# ...
